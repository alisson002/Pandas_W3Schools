# %% [markdown]
# # Empty Cells
# Empty cells can potentially give you a wrong result when you analyze data.
#
# ## Remove Rows
# One way to deal with empty cells is to remove rows that contain empty cells.
#
# This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.

# %%
import pandas as pd

# %%
import numpy as np
# Método 2: Criando manualmente com dicionário
data = {
    'Duration': [60, 60, 60, 45, 45, 60, 60, 450, 30, 60, 60, 60, 60, 60, 60, 60, 60, 60, 45, 60, 45, 60, 45, 60, 45, 60, 60, 60, 60, 60, 60, 60],
    'Date': ['2020/12/01', '2020/12/02', '2020/12/03', '2020/12/04', '2020/12/05', '2020/12/06', '2020/12/07', '2020/12/08', '2020/12/09', '2020/12/10', '2020/12/11', '2020/12/12', '2020/12/12', '2020/12/13', '2020/12/14', '2020/12/15', '2020/12/16', '2020/12/17', '2020/12/18', '2020/12/19', '2020/12/20', '2020/12/21', np.nan, '2020/12/23', '2020/12/24', '2020/12/25', 2020/12/26, '2020/12/27', '2020/12/28', '2020/12/29', '2020/12/30', '2020/12/31'],
    'Pulse': [110, 117, 103, 109, 117, 102, 110, 104, 109, 98, 103, 100, 100, 106, 104, 98, 98, 100, 90, 103, 97, 108, 100, 130, 105, 102, 100, 92, 103, 100, 102, 92],
    'Maxpulse': [130, 145, 135, 175, 148, 127, 136, 134, 133, 124, 147, 120, 120, 128, 132, 123, 120, 120, 112, 123, 125, 131, 119, 101, 132, 126, 120, 118, 132, 132, 129, 115],
    'Calories': [409.1, 479.0, 340.0, 282.4, 406.0, 300.0, 374.0, 253.3, 195.1, 269.0, 329.3, 250.7, 250.7, 345.3, 379.3, 275.0, 215.2, 300.0, np.nan, 323.0, 243.0, 364.2, 282.0, 300.0, 246.0, 334.5, 250.0, 241.0, np.nan, 280.0, 380.3, 243.0]
}

df = pd.DataFrame(data)

print("\n" + "="*50) # Separador visual
print("DataFrame criado manualmente:")
# print(df)
print(df)  # Exemplo de célula vazia

df.to_csv('dataForDC.csv', index=False)
# Out:
# ...
# DataFrame criado manualmente:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# ...

# %%
df = pd.read_csv('dataForDC.csv')

# %%
# Novo df sem células vazias. Remove todas as linhas que possuem ao menos uma célula vazia (NaN).
# Por padrão, o método dropna() retorna um novo DataFrame, e não altera o original.
new_df = df.dropna()

print(new_df.to_string())

new_df
# Out:
#     Duration                Date  Pulse  Maxpulse  Calories
# 0         60          2020/12/01    110       130     409.1
# 1         60          2020/12/02    117       145     479.0
# 2         60          2020/12/03    103       135     340.0
# 3         45          2020/12/04    109       175     282.4
# 4         45          2020/12/05    117       148     406.0
# 5         60          2020/12/06    102       127     300.0
# 6         60          2020/12/07    110       136     374.0
# 7        450          2020/12/08    104       134     253.3
# 8         30          2020/12/09    109       133     195.1
# 9         60          2020/12/10     98       124     269.0
# 10        60          2020/12/11    103       147     329.3
# 11        60          2020/12/12    100       120     250.7
# 12        60          2020/12/12    100       120     250.7
# 13        60          2020/12/13    106       128     345.3
# 14        60          2020/12/14    104       132     379.3
# ...

# %%
# Caso queira salvar o novo DataFrame com alterações do dropna usamos implace = True
# df = pd.read_csv('dataForDC.csv')

df.dropna(inplace = True)

print(df.to_string())

# Nesse caso não retorna um novo DataFrame, mas altera o original.
# Out:
#     Duration                Date  Pulse  Maxpulse  Calories
# 0         60          2020/12/01    110       130     409.1
# 1         60          2020/12/02    117       145     479.0
# 2         60          2020/12/03    103       135     340.0
# 3         45          2020/12/04    109       175     282.4
# 4         45          2020/12/05    117       148     406.0
# 5         60          2020/12/06    102       127     300.0
# 6         60          2020/12/07    110       136     374.0
# 7        450          2020/12/08    104       134     253.3
# 8         30          2020/12/09    109       133     195.1
# 9         60          2020/12/10     98       124     269.0
# 10        60          2020/12/11    103       147     329.3
# 11        60          2020/12/12    100       120     250.7
# 12        60          2020/12/12    100       120     250.7
# 13        60          2020/12/13    106       128     345.3
# 14        60          2020/12/14    104       132     379.3
# ...

# %% [markdown]
# ## Replace Empty Values
# Another way of dealing with empty cells is to insert a new value instead.
#
# This way you do not have to delete entire rows just because of some empty cells.
#
# The fillna() method allows us to replace empty cells with a value:

# %%
# Preenchendo uam celula com com o numero 130

df = pd.read_csv('dataForDC.csv')

df_preenchdo130 = df.fillna(130)

df_preenchdo130 # Onde era NaN agora é 130
# Out:
#     Duration                Date  Pulse  Maxpulse  Calories
# 0         60          2020/12/01    110       130     409.1
# 1         60          2020/12/02    117       145     479.0
# 2         60          2020/12/03    103       135     340.0
# 3         45          2020/12/04    109       175     282.4
# 4         45          2020/12/05    117       148     406.0
# 5         60          2020/12/06    102       127     300.0
# 6         60          2020/12/07    110       136     374.0
# 7        450          2020/12/08    104       134     253.3
# 8         30          2020/12/09    109       133     195.1
# 9         60          2020/12/10     98       124     269.0
# 10        60          2020/12/11    103       147     329.3
# 11        60          2020/12/12    100       120     250.7
# 12        60          2020/12/12    100       120     250.7
# 13        60          2020/12/13    106       128     345.3
# 14        60          2020/12/14    104       132     379.3
# ...

# %%
# Preenchendo uam celula com com o numero 130

# Tb pode ser usado inplace = True

df = pd.read_csv('dataForDC.csv')

df.fillna(130, inplace = True)

df # Onde era NaN agora é 130
# Out:
#     Duration                Date  Pulse  Maxpulse  Calories
# 0         60          2020/12/01    110       130     409.1
# 1         60          2020/12/02    117       145     479.0
# 2         60          2020/12/03    103       135     340.0
# 3         45          2020/12/04    109       175     282.4
# 4         45          2020/12/05    117       148     406.0
# 5         60          2020/12/06    102       127     300.0
# 6         60          2020/12/07    110       136     374.0
# 7        450          2020/12/08    104       134     253.3
# 8         30          2020/12/09    109       133     195.1
# 9         60          2020/12/10     98       124     269.0
# 10        60          2020/12/11    103       147     329.3
# 11        60          2020/12/12    100       120     250.7
# 12        60          2020/12/12    100       120     250.7
# 13        60          2020/12/13    106       128     345.3
# 14        60          2020/12/14    104       132     379.3
# ...

# %% [markdown]
# ## Replace Only For Specified Columns
# The example above replaces all empty cells in the whole Data Frame.
#
# To only replace empty values for one column, specify the column name for the DataFrame:

# %%
df = pd.read_csv('dataForDC.csv')

df.fillna({"Calories": 130}, inplace=True) # Substitui apenas em colunas especificas. Nesse caso subistituindo os NULL Values por 130.

df
# Out:
#     Duration                Date  Pulse  Maxpulse  Calories
# 0         60          2020/12/01    110       130     409.1
# 1         60          2020/12/02    117       145     479.0
# 2         60          2020/12/03    103       135     340.0
# 3         45          2020/12/04    109       175     282.4
# 4         45          2020/12/05    117       148     406.0
# 5         60          2020/12/06    102       127     300.0
# 6         60          2020/12/07    110       136     374.0
# 7        450          2020/12/08    104       134     253.3
# 8         30          2020/12/09    109       133     195.1
# 9         60          2020/12/10     98       124     269.0
# 10        60          2020/12/11    103       147     329.3
# 11        60          2020/12/12    100       120     250.7
# 12        60          2020/12/12    100       120     250.7
# 13        60          2020/12/13    106       128     345.3
# 14        60          2020/12/14    104       132     379.3
# ...

# %% [markdown]
# ## Replace Using Mean, Median, or Mode
# A common way to replace empty cells, is to calculate the mean, median or mode value of the column.
#
# Pandas uses the mean() median() and mode() methods to calculate the respective values for a specified column:

# %%
df = pd.read_csv('dataForDC.csv')

x = df['Calories'].mean() #calcula a média da coluna
# O mesmo serve para .median() que pega o valor do meio e .mode() o valor que aparece com mais frequencia.

df.fillna({'Calories': x}, inplace=True) # substitui os NULL pela média da coluna

df
# Out:
#     Duration                Date  Pulse  Maxpulse  Calories
# 0         60          2020/12/01    110       130    409.10
# 1         60          2020/12/02    117       145    479.00
# 2         60          2020/12/03    103       135    340.00
# 3         45          2020/12/04    109       175    282.40
# 4         45          2020/12/05    117       148    406.00
# 5         60          2020/12/06    102       127    300.00
# 6         60          2020/12/07    110       136    374.00
# 7        450          2020/12/08    104       134    253.30
# 8         30          2020/12/09    109       133    195.10
# 9         60          2020/12/10     98       124    269.00
# 10        60          2020/12/11    103       147    329.30
# 11        60          2020/12/12    100       120    250.70
# 12        60          2020/12/12    100       120    250.70
# 13        60          2020/12/13    106       128    345.30
# 14        60          2020/12/14    104       132    379.30
# ...
